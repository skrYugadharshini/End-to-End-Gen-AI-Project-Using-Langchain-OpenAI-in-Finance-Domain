# %%
pip install langchain-community
# Out:
# Collecting langchain-communityNote: you may need to restart the kernel to use updated packages.
#
#   Downloading langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langchain-community) (1.2.7)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain-community)
#   Downloading langchain_classic-1.0.1-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langchain-community) (2.0.34)
# Collecting requests<3.0.0,>=2.32.5 (from langchain-community)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langchain-community) (3.10.5)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langchain-community) (8.2.3)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain-community)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain-community)
#   Downloading pydantic_settings-2.12.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langchain-community) (0.6.7)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.11.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-text-splitters<2.0.0,>=1.1.0 (from langchain-classic<2.0.0,>=1.0.0->langchain-community)
#   Downloading langchain_text_splitters-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.8.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (23.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (4.11.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (0.14.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.27.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.6)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.21.0)
# Collecting typing-inspection>=0.4.0 (from pydantic-settings<3.0.0,>=2.10.1->langchain-community)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.0.1)
# Requirement already satisfied: anyio in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain-community) (2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.20.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.0.0)
# Collecting typing-extensions<5.0.0,>=4.7.0 (from langchain-core<2.0.0,>=1.0.1->langchain-community)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Downloading langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.5 MB 74.6 kB/s eta 0:00:27
#    -------- ------------------------------- 0.5/2.5 MB 74.6 kB/s eta 0:00:27
#    -------- ------------------------------- 0.5/2.5 MB 74.6 kB/s eta 0:00:27
#    -------- ------------------------------- 0.5/2.5 MB 74.6 kB/s eta 0:00:27
#    -------- ------------------------------- 0.5/2.5 MB 74.6 kB/s eta 0:00:27
#    -------- ------------------------------- 0.5/2.5 MB 74.6 kB/s eta 0:00:27
#    -------- ------------------------------- 0.5/2.5 MB 74.6 kB/s eta 0:00:27
#    -------- ------------------------------- 0.5/2.5 MB 74.6 kB/s eta 0:00:27
#    -------- ------------------------------- 0.5/2.5 MB 74.6 kB/s eta 0:00:27
#    -------- ------------------------------- 0.5/2.5 MB 74.6 kB/s eta 0:00:27
#    ------------ --------------------------- 0.8/2.5 MB 94.0 kB/s eta 0:00:19
#    ------------ --------------------------- 0.8/2.5 MB 94.0 kB/s eta 0:00:19
#    ---------------- ----------------------- 1.0/2.5 MB 131.1 kB/s eta 0:00:12
#    ---------------- ----------------------- 1.0/2.5 MB 131.1 kB/s eta 0:00:12
#    ---------------- ----------------------- 1.0/2.5 MB 131.1 kB/s eta 0:00:12
#    -------------------- ------------------- 1.3/2.5 MB 157.5 kB/s eta 0:00:08
#    -------------------- ------------------- 1.3/2.5 MB 157.5 kB/s eta 0:00:08
#    ------------------------ --------------- 1.6/2.5 MB 188.9 kB/s eta 0:00:06
#    ---------------------------- ----------- 1.8/2.5 MB 219.3 kB/s eta 0:00:04
#    ---------------------------- ----------- 1.8/2.5 MB 219.3 kB/s eta 0:00:04
#    ---------------------------- ----------- 1.8/2.5 MB 219.3 kB/s eta 0:00:04
#    ---------------------------- ----------- 1.8/2.5 MB 219.3 kB/s eta 0:00:04
#    ---------------------------- ----------- 1.8/2.5 MB 219.3 kB/s eta 0:00:04
#    ---------------------------- ----------- 1.8/2.5 MB 219.3 kB/s eta 0:00:04
#    ---------------------------- ----------- 1.8/2.5 MB 219.3 kB/s eta 0:00:04
#    ---------------------------- ----------- 1.8/2.5 MB 219.3 kB/s eta 0:00:04
#    ---------------------------- ----------- 1.8/2.5 MB 219.3 kB/s eta 0:00:04
#    ---------------------------- ----------- 1.8/2.5 MB 219.3 kB/s eta 0:00:04
#    ---------------------------- ----------- 1.8/2.5 MB 219.3 kB/s eta 0:00:04
#    --------------------------------- ------ 2.1/2.5 MB 195.1 kB/s eta 0:00:03
#    --------------------------------- ------ 2.1/2.5 MB 195.1 kB/s eta 0:00:03
#    --------------------------------- ------ 2.1/2.5 MB 195.1 kB/s eta 0:00:03
#    --------------------------------- ------ 2.1/2.5 MB 195.1 kB/s eta 0:00:03
#    ------------------------------------- -- 2.4/2.5 MB 205.2 kB/s eta 0:00:01
#    ------------------------------------- -- 2.4/2.5 MB 205.2 kB/s eta 0:00:01
#    ------------------------------------- -- 2.4/2.5 MB 205.2 kB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 209.7 kB/s eta 0:00:00
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading langchain_classic-1.0.1-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    -------------------- ------------------- 0.5/1.0 MB 110.4 kB/s eta 0:00:05
#    -------------------- ------------------- 0.5/1.0 MB 110.4 kB/s eta 0:00:05
#    -------------------- ------------------- 0.5/1.0 MB 110.4 kB/s eta 0:00:05
#    -------------------- ------------------- 0.5/1.0 MB 110.4 kB/s eta 0:00:05
#    -------------------- ------------------- 0.5/1.0 MB 110.4 kB/s eta 0:00:05
#    -------------------- ------------------- 0.5/1.0 MB 110.4 kB/s eta 0:00:05
#    ------------------------------ --------- 0.8/1.0 MB 146.5 kB/s eta 0:00:02
#    ---------------------------------------- 1.0/1.0 MB 205.0 kB/s eta 0:00:00
# Downloading pydantic_settings-2.12.0-py3-none-any.whl (51 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading langchain_text_splitters-1.1.0-py3-none-any.whl (34 kB)
# Downloading marshmallow-3.26.2-py3-none-any.whl (50 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Installing collected packages: typing-extensions, requests, marshmallow, httpx-sse, typing-inspection, typing-inspect, dataclasses-json, pydantic-settings, langchain-text-splitters, langchain-classic, langchain-community
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.11.0
#     Uninstalling typing_extensions-4.11.0:
#       Successfully uninstalled typing_extensions-4.11.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
# Successfully installed dataclasses-json-0.6.7 httpx-sse-0.4.3 langchain-classic-1.0.1 langchain-community-0.4.1 langchain-text-splitters-1.1.0 marshmallow-3.26.2 pydantic-settings-2.12.0 requests-2.32.5 typing-extensions-4.15.0 typing-inspect-0.9.0 typing-inspection-0.4.2
# [notice] A new release of pip is available: 24.3.1 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install -U langchain langchain-community
# Out:
# Requirement already satisfied: langchain in c:\users\lenovo\anaconda3\new folder\lib\site-packages (1.2.7)
# Collecting langchain
#   Downloading langchain-1.2.9-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: langchain-community in c:\users\lenovo\anaconda3\new folder\lib\site-packages (0.4.1)
# Collecting langchain-core<2.0.0,>=1.2.9 (from langchain)
#   Downloading langchain_core-1.2.9-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.7 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langchain) (1.0.7)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langchain) (2.8.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langchain-community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langchain-community) (2.0.34)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langchain-community) (3.10.5)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langchain-community) (8.2.3)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.11.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langchain-core<2.0.0,>=1.2.9->langchain) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from langchain-core<2.0.0,>=1.2.9->langchain) (23.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langchain-core<2.0.0,>=1.2.9->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langchain-core<2.0.0,>=1.2.9->langchain) (0.14.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langgraph<1.1.0,>=1.0.7->langchain) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.7 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langgraph<1.1.0,>=1.0.7->langchain) (1.0.7)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langgraph<1.1.0,>=1.0.7->langchain) (0.3.3)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langgraph<1.1.0,>=1.0.7->langchain) (3.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.27.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.6)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.20.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.21.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.0.1)
# Requirement already satisfied: anyio in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.9->langchain) (2.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.7->langchain) (1.12.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\lenovo\anaconda3\new folder\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.0.0)
# Downloading langchain-1.2.9-py3-none-any.whl (111 kB)
# Downloading langchain_core-1.2.9-py3-none-any.whl (496 kB)
# Installing collected packages: langchain-core, langchain
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.2.7
#     Uninstalling langchain-core-1.2.7:
#       Successfully uninstalled langchain-core-1.2.7
#   Attempting uninstall: langchain
#     Found existing installation: langchain 1.2.7
#     Uninstalling langchain-1.2.7:
#       Successfully uninstalled langchain-1.2.7
# Successfully installed langchain-1.2.9 langchain-core-1.2.9
# [notice] A new release of pip is available: 24.3.1 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_community.document_loaders import TextLoader

# %%
loader =TextLoader("nvda_news_1.txt")
data = loader.load()
data
# Out:
# [Document(metadata={'source': 'nvda_news_1.txt'}, page_content="The stock of NVIDIA Corp (NASDAQ:NVDA) experienced a daily loss of -3.56% and a 3-month gain of 32.35%. With an Earnings Per Share (EPS) (EPS) of $1.92, the question arises: is the stock significantly overvalued? This article aims to provide a detailed valuation analysis of NVIDIA, offering insights into its financial strength, profitability, growth, and more. We invite you to delve into this comprehensive analysis.\n\nCompany Overview\nWarning! GuruFocus has detected 10 Warning Signs with NVDA. Click here to check it out.\n\nNVDA 30-Year Financial Data\n\nThe intrinsic value of NVDA\n\n\nNVIDIA Corp (NASDAQ:NVDA) is a leading designer of discrete graphics processing units that enhance the experience on computing platforms. The firm's chips are widely used in various end markets, including PC gaming and data centers. In recent years, NVIDIA has broadened its focus from traditional PC graphics applications such as gaming to more complex and favorable opportunities, including artificial intelligence and autonomous driving, leveraging the high-performance capabilities of its products.\n\nCurrently, NVIDIA's stock price stands at $418.01, significantly higher than the GF Value of $310.28, indicating the stock might be overvalued. With a market cap of $1 trillion, the valuation seems steep. The following analysis aims to delve deeper into the company's value.\n\nIs NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis\nIs NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis\nUnderstanding the GF Value\nThe GF Value is a unique measure of the intrinsic value of a stock, calculated based on historical trading multiples, a GuruFocus adjustment factor, and future business performance estimates. If the stock price is significantly above the GF Value Line, it is overvalued, and its future return is likely to be poor. Conversely, if it is significantly below the GF Value Line, its future return will likely be higher.\n\nAccording to GuruFocus Value calculation, NVIDIA (NASDAQ:NVDA) appears to be significantly overvalued. The stock's current price of $418.01 per share and the market cap of $1 trillion further strengthen this assumption.\n\nGiven that NVIDIA is significantly overvalued, the long-term return of its stock is likely to be much lower than its future business growth.\n\nIs NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis\nIs NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis\nLink: These companies may deliver higher future returns at reduced risk.\n\nFinancial Strength of NVIDIA\nExamining the financial strength of a company is crucial before investing in its stock. Companies with poor financial strength pose a higher risk of permanent loss. NVIDIA's cash-to-debt ratio of 1.27 is worse than 58.04% of companies in the Semiconductors industry. However, NVIDIA's overall financial strength is 8 out of 10, indicating a strong financial position.\n\nIs NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis\nIs NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis\nProfitability and Growth\nConsistent profitability over the long term reduces the risk for investors. NVIDIA, with its profitability ranking of 10 out of 10, has been profitable for the past 10 years. The company's operating margin of 17.37% ranks better than 76.5% of companies in the Semiconductors industry.\n\nHowever, growth is a crucial factor in a company's valuation. NVIDIA's growth ranks worse than 52.99% of companies in the Semiconductors industry, with its 3-year average revenue growth rate better than 87.88% of companies in the industry.\n\nROIC vs WACC\nComparing a company's return on invested capital (ROIC) to its weighted average cost of capital (WACC) is an effective way to evaluate its profitability. Over the past 12 months, NVIDIA's ROIC was 20.32 while its W ...

# %%
loader = TextLoader("nvda_news_1.txt")
data = loader.load()

# %%
import os
print(os.path.exists("nvda_news_1.txt"))
# Out:
# True

# %%
data[0].metadata
# Out:
# {'source': 'nvda_news_1.txt'}

# %%
from langchain_community.document_loaders import CSVLoader
